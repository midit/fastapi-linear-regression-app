# %% [markdown]
# # LAB 04 NTPD
# <small> Wykonał: Maksym Patrushev </small>

# %% [markdown]
# # Cel ćwiczenia:
# Celem ćwiczenia jest tworzenie obrazu Dockera z modelem ML; uruchamianie kontenera i testowanie endpointów; konfiguracja Docker Compose dla aplikacji ML.

# %% [markdown]
# # Zadanie 1: Przygotowanie aplikacji API

# %% [markdown]
# Użyłem `pip freeze > requirements.txt` do stworzenia pliku z potrzebnymi bibliotekami oraz zainstalowałem Docker na do mojego systemu

# %% [markdown]
# # Zadanie 2: Dockerfile i budowa obrazu

# %% [markdown]
# Utworzyłem plik o nazwie Dockerfile oraz dodałem instrukcje do zbudowania obrazu.

# %% [markdown]
# Zbudowałem obraz lokalnie i sprawdziłem czy został utworzony używając Docker Desktop.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# # Zadanie 3: Uruchamianie kontenera i testowanie endpointu

# %% [markdown]
# Uruchomiłem kontener używając polecenia `docker run -p 8000:8000 my-app`

# %% [markdown]
# Sprawdziłem że kontener wystawia port `8000`

# %% [markdown]
# Przetestowałem endpoint `POST /predict` używając polecenia **cURL**.
